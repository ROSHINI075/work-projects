# %% [markdown]
# <a href="https://colab.research.google.com/github/ROSHINI075/work-projects/blob/main/Python_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 6
y = 6
print(x==y)
# Out:
# True

# %%
x=5
y=7
print(x!=y)
# Out:
# True

# %%
x=55
y=77
print(x<y)
# Out:
# True

# %%
a = input("Enter the number:")
b = input("Enter the number:")
print(a<b)
# Out:
# Enter the number:45
# Enter the number:75
# True

# %%
age = int(input("Enter the age:"))
if age >= 12:
  print("Teenager")
if age >= 18:
  print("Major")
if age >= 23:
  print("Eligiable to marry")
# Out:
# Enter the age:12
# Teenager

# %%
marks = 75
if marks >=90:
  print("Grade: A")
elif marks >=60:
  print("Grade: B")
elif marks >=40:
  print("Grade: C")
else:
  print("Fail")
# Out:
# Grade: B

# %%
a = int(input("Enter the number:"))
b = int(input("Enter the number:"))
print((a<b)and(a!=b))
# Out:
# Enter the number:25
# Enter the number:75
# True

# %%
is_logged_in = True
if not is_logged_in:
    print("Please log in")
else:
    print("Welcome back")
# Out:
# Welcome back

# %%
P = 3.1890
print(round(P,2))
print(type(P))
o_p = int(2.890)
print(type(o_p))
# Out:
# 3.19
# <class 'float'>
# <class 'int'>

# %%
C1 = complex(3,2)
C2 = complex(1,2)
print(C1)
print(C2)
print(C1.real)
print(C2.imag)
# Out:
# (3+2j)
# (1+2j)
# 3.0
# 2.0

# %%
a = 12
result = a>>1
print(result)
# Out:
# 6

# %%
letter = "R"
print(type(letter))
# Out:
# <class 'str'>

# %%
x = "paris"
y = "Destinations"
Note = """Plan for your destinations
start from dream
_peace_lesson_joy
begin!"""
print(Note)
# Out:
# Plan for your destinations
# start from dream
# _peace_lesson_joy
# begin!

# %%
s = "ONEPIECE"
print(s[0])
print(s[-5])
# Out:
# O
# P

# %%
v = "python"
print(v[0:6])
print(v[2:])
print(v[:3])
# Out:
# python
# thon
# pyt

# %%
t = "12345678910"
print(t[0:10:2])
# Out:
# 13579

# %%
a = "Data"
b = "Science"
print(a+ " " +b)
# Out:
# Data Science

# %%
word = "HI"
print(word*12)
# Out:
# HIHIHIHIHIHIHIHIHIHIHIHI

# %%
word = "HI"
print((word+"\n")*12)
# Out:
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI
# HI

# %%
print("apple"=="Apple")
# Out:
# False

# %%
text = "data analytics"
print(len(text))
# Out:
# 14
